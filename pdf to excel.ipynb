# %%
import tabula
import pandas as pd
import numpy as np

# %%
pdf = 'Data/Greenwich owner_statement_report.pdf'

# %%
table_dfs = []

# %%
table = tabula.read_pdf(pdf, pages='1')
table_df = table[1]
table_dfs.append(table_df)
table_df
# Out:
#           Date         Payee / Payer     Type  Reference  \
# 0          NaN                   NaN      NaN        NaN
# 1   08/01/2023     jastan N.\rburnes  Receipt        NaN
# 2   08/01/2023     jastan N.\rburnes  Receipt        NaN
# 3   08/01/2023     jastan N.\rburnes  Receipt        NaN
# 4   08/01/2023          Jarod Turner  Receipt        NaN
# 5   08/01/2023         Justin Vargas  Receipt        NaN
# 6   08/01/2023    Whitney S.\rHunter  Receipt        NaN
# 7   08/01/2023    Whitney S.\rHunter  Receipt        NaN
# 8   08/01/2023    Whitney S.\rHunter  Receipt        NaN
# 9   08/01/2023          Kaitlin Ginn  Receipt        NaN
# 10  08/01/2023          Kaitlin Ginn  Receipt        NaN
# 11  08/01/2023          Kaitlin Ginn  Receipt        NaN
# 12  08/01/2023          Kaitlin Ginn  Receipt        NaN
# 13  08/01/2023     Ethan A.\rShelton  Receipt        NaN
# 14  08/01/2023     Ethan A.\rShelton  Receipt        NaN
# ...

# %%
table = tabula.read_pdf(pdf, pages='2')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#           Date                  Payee / Payer             Type    Reference  \
# 0          NaN                            NaN          receipt          NaN
# 1   08/01/2023                   Zonnie Kilah  eCheck\rreceipt    03B0-EDA0
# 2   08/01/2023                    Coby Potvin      CC\rreceipt    0525-4240
# 3   08/01/2023            Marta T.\rNovakovic      CC\rreceipt    12DE-0780
# 4   08/01/2023           Bethany R.\rWilliams      CC\rreceipt    1815-8F10
# 5   08/01/2023                 Aidan\rMcGeown      CC\rreceipt    A92E-B650
# 6   08/01/2023  Andrei Cristian\rGalca Mitran      CC\rreceipt    1FEF-40F0
# 7   08/01/2023                  Rochelle Diaz          Receipt  28769194170
# 8   08/01/2023         GUSTAVO P.\rGIESBRECHT  eCheck\rreceipt    E71E-7A60
# 9   08/02/2023               Sailor A. Fritts          Receipt          NaN
# 10  08/02/2023                Axel\rRunarsson      CC\rreceipt    1112-5FB0
# ...

# %%
table = tabula.read_pdf(pdf, pages='3')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#           Date                        Payee / Payer             Type  \
# 0          NaN                                  NaN              NaN
# 1   08/03/2023                      Tiffany Huffins            Check
# 2   08/03/2023                      Tiffany Huffins            Check
# 3   08/03/2023                      Tiffany Huffins            Check
# 4   08/03/2023                      Tiffany Huffins            Check
# 5   08/03/2023                      Tiffany Huffins            Check
# 6   08/03/2023  Grunt Works\rProperty\rImprovements            Check
# 7   08/04/2023                  Fabian A.\rMartinez      CC\rreceipt
# 8   08/04/2023                          Jerry Nunez          Receipt
# 9   08/04/2023                       John E. Taylor          Receipt
# 10  08/04/2023                   Nathan B.\rHawkins          Receipt
# 11  08/04/2023                          Cody Parker          Receipt
# 12  08/04/2023                          Cody Parker          Receipt
# ...

# %%
table = tabula.read_pdf(pdf, pages='5')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#           Date                        Payee / Payer  \
# 0   08/14/2023                   Justin\rDeMoulpied
# 1   08/14/2023                   Justin\rDeMoulpied
# 2   08/14/2023                                  NaN
# 3   08/14/2023         Metro\rAppliance &\rMore Inc
# 4   08/14/2023                   Justice M.\rYarmon
# 5   08/14/2023                   Justice M.\rYarmon
# 6   08/15/2023               Sullivan\rConstruction
# 7   08/17/2023                      Tiffany Huffins
# 8   08/17/2023                      Tiffany Huffins
# 9   08/17/2023                      Tiffany Huffins
# 10  08/17/2023           Silvia Onely\rVega Sanchez
# 11  08/17/2023                    Entergy-\rGeneral
# 12  08/17/2023                           Home Depot
# 13  08/17/2023                           Home Depot
# 14  08/17/2023                           Home Depot
# 15  08/17/2023                           Home Depot
# 16  08/18/2023  Grunt Works\rProperty\rImprovements
# ...

# %%
table = tabula.read_pdf(pdf, pages='7')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#           Date                    Payee / Payer             Type  Reference  \
# 0   08/28/2023  Rich Realty of\rBatesville, Inc            Check       8305
# 1   08/28/2023               Justice M.\rYarmon  eCheck\rreceipt  C534-C5A0
# 2   08/30/2023                  Tiffany Huffins            Check       8313
# 3   08/30/2023                Entergy-\rGeneral            Check       8315
# 4   08/30/2023     Eagle Pest\rManagement\rLLC.            Check       8316
# 5   08/31/2023                McClure\rPlumbing            Check       8321
# 6   08/31/2023       Silvia Onely\rVega Sanchez            Check       8325
# 7   09/01/2023                Ethan A.\rShelton          Receipt        NaN
# 8   09/01/2023                Ethan A.\rShelton          Receipt        NaN
# 9   09/01/2023                jastan N.\rburnes          Receipt        NaN
# 10  09/01/2023                jastan N.\rburnes          Receipt        NaN
# ...

# %%
table = tabula.read_pdf(pdf, pages='8')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#           Date                  Payee / Payer             Type  \
# 0          NaN                        Medrano              NaN
# 1   09/01/2023                  Joe D. Rocole          Receipt
# 2   09/01/2023                    Lidia Kilah  eCheck\rreceipt
# 3   09/01/2023                   Zonnie Kilah  eCheck\rreceipt
# 4   09/01/2023                    Coby Potvin      CC\rreceipt
# 5   09/01/2023            Marta T.\rNovakovic      CC\rreceipt
# 6   09/01/2023              jastan N.\rburnes          Receipt
# 7   09/01/2023  Andrei Cristian\rGalca Mitran  eCheck\rreceipt
# 8   09/01/2023             Whitney S.\rHunter          Receipt
# 9   09/01/2023             Whitney S.\rHunter          Receipt
# 10  09/01/2023                Krystle L. Bolt      CC\rreceipt
# 11  09/01/2023                Krystle L. Bolt      CC\rreceipt
# 12  09/01/2023             Jackson W.\rHarrod          Receipt
# 13  09/01/2023                 Amanda\rGrooms            Check
# ...

# %%
table = tabula.read_pdf(pdf, pages='9')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#           Date                        Payee / Payer             Type  \
# 0   09/04/2023                       Aidan\rMcGeown      CC\rreceipt
# 1   09/04/2023                        Ronaldo Jacob      CC\rreceipt
# 2   09/04/2023                      Axel\rRunarsson      CC\rreceipt
# 3   09/04/2023                  Fabian A.\rMartinez      CC\rreceipt
# 4   09/05/2023                      Axel\rRunarsson      CC\rreceipt
# 5   09/05/2023                          Rickey Love          Receipt
# 6   09/05/2023                    Ashlyn\rRoutledge  eCheck\rreceipt
# 7   09/05/2023                       Rafael\rCampos      CC\rreceipt
# 8   09/05/2023               Sullivan\rConstruction            Check
# 9   09/05/2023                    McClure\rPlumbing            Check
# 10  09/05/2023                    McClure\rPlumbing            Check
# 11  09/05/2023                    McClure\rPlumbing            Check
# 12  09/05/2023                           Judy Ellis          Receipt
# ...

# %%
table = tabula.read_pdf(pdf, pages='10')
table_df = table[0]
table_dfs.append(table_df)
table_df
# Out:
#                       Date                    Payee / Payer    Type  \
# 0               09/08/2023  Rich Realty of\rBatesville, Inc   Check
# 1               09/08/2023  Rich Realty of\rBatesville, Inc   Check
# 2               09/08/2023          Greenwich\rVillage, LLC  eCheck
# 3                      NaN                              NaN     NaN
# 4  Total57,047.0554,047.05                              NaN     NaN
#
#    Reference                                        Description  Income  \
# 0       8385  Unit 9 - Lease Renewal 1/4 fee - Lease Renewal...     NaN
# 1       8388                    Mgn Fees - Mgn Fees for 08/2023     NaN
# 2  2CCB-5E18             Owner Draw - Owner payment for 09/2023     NaN
# 3        NaN                                Ending Cash Balance     NaN
# 4        NaN                                                NaN     NaN
#
#      Expense    Balance
# 0     181.25  21,232.07
# 1      53.50  21,178.57
# 2  18,178.57   3,000.00
# ...

# %%
len(table_dfs)
# Out:
# 8

# %%
table_dfs[7].to_excel('Data/1.xlsx',index = False)
